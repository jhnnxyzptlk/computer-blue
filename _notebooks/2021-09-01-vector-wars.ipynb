# %% [markdown]
# # The Vector Algebra War
# > A course summary
#
# - toc: true
# - branch: master
# - badges: true
# - comments: true
# - author: Johann Augustine
# - image: images/
# - categories: [mathematics]
# - hide: true

# %% [markdown]
# # Overview
#
# There are several vector formalisms that are now used in engineering and science.
