# %% [markdown]
# # Learning How to Learn
# > A course summary
#
# - toc: true
# - branch: master
# - badges: true
# - comments: true
# - author: Johann Augustine
# - image: images/
# - categories: []
# - hide: true

# %% [markdown]
# # Overview

# %% [markdown]
# ## Introduction to the Focused and Diffuse Modes
