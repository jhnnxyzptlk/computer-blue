# %% [markdown]
# # Physics of Consciousness
# > Awesome summary
#
# - toc: true
# - branch: master
# - badges: true
# - comments: true
# - author: Johann Augustine
# - categories: [mathematics, python]

# %%
http://www.goldenmean.info/ai/index.html
