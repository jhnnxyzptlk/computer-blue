# %% [markdown]
# # Numerical Errors
# > How to manage computer errors
#
# - toc: true
# - badges: true
# - comments: true
# - categories: [mathematics, computer-science]
# - image: images/ .jpeg
# - hide: true
