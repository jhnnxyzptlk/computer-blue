# %% [markdown]
# # What I learned about memory
# > or how I learned to forget what's not important
#
# - toc: true
# - badges: true
# - comments: true
# - author: Johann Augustine
# - image: images/NYC-harbor.jpg
# - categories: [memory, neuroscience, brain]
# - hide: true

# %% [markdown]
# ## Setting Yourself Up For Success

# %% [markdown]
# ## Understanding Your Memory

# %% [markdown]
# ## The Power Of Visual Memory

# %% [markdown]
# ## Maintaining Long Term Memories

# %% [markdown]
# ## Pre-reading And Preparation

# %% [markdown]
# ## Read With Your Eyes, Not With Your Inner Voice

# %% [markdown]
# ## Good Learning Habits
