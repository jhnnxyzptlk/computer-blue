# %% [markdown]
# # Python under the Hood
# > Awesome summary
#
# - toc: true
# - branch: master
# - badges: true
# - comments: true
# - author: Johann Augustine
# - categories: [computer-science, python, c-lang]
# - hide: true

# %% [markdown]
# ## Overview
#
# > Note: If you dont know C, [CS50](https://cs50.harvard.edu/x/2021/notes/1/) is a great place to start.
