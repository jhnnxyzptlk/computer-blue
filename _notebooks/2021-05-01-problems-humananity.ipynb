# %% [markdown]
# # What is the most important problem facing humanity?
# > Awesome summary
#
# - toc: true
# - branch: master
# - badges: true
# - comments: true
# - author: Johann Augustine
# - categories: [physics]

# %% [markdown]
# ## Overview
#
# Over time, I began to ask myself "What is the most important problem facing humanity?" I found two answers:
#
# 1) Electrical energy generation and
#
# 2) Medical/Health issues.
#
# On the following web pages, I will post items which I find of interest concerning the generation of electrical energy.
#
# With all this false talk of bitcoin consuming too much energy.
