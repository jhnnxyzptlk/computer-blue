# %% [markdown]
# # What is the most important problem facing humanity?
# > Awesome summary
#
# - toc:true- branch: master
# - badges: true
# - comments: true
# - author: Johann Augustine
# - categories: [physics]

# %% [markdown]
# ## Overview
#
# With all this false talk of bitcoin consuming too much energy.
#
# Over time, I began to ask myself "What is the most important problem facing humanity?" I found two answers: 1) Electrical energy generation and 2) Medical/Health issues. Since I am not in any way educated in Medical/Health issues, whereas I do have some Physics training, I decided that I had better spend my time researching electrical energy generation.
#
# On the following web pages, I will post items which I find of interest concerning the generation of electrical energy.

# %%
http://www.rwgrayprojects.com/energy/energy01.html
