# %% [markdown]
# # The Neuroanatomy of ADHD
# >
#
# - toc: true
# - badges: true
# - comments: true
# - author: Johann Augustine
# - image: images/
# - categories: [nueroscience, brain]

# %% [markdown]
# # "Title"
# > "Awesome summary"
#
# - toc: false
# - branch: master
# - badges: true
# - comments: true
# - categories: [fastpages, jupyter]
# - image: images/some_folder/your_image.png
# - hide: false
# - search_exclude: true
# - metadata_key1: metadata_value1
# - metadata_key2: metadata_value2

# %% [markdown]
# ## Overview

# %% [markdown]
# ## Disorder of the Executive Funtioning

# %% [markdown]
# ## Brain Parts

# %% [markdown]
# ## ADHD without the Drugs
#
# >note: I am not a western medicine doctor.

# %% [markdown]
# ## Closing Remarks
